# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
filepath="/content/drive/MyDrive/CAR DETAILS FROM CAR DEKHO (1).csv"

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(filepath)

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
df.isna().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
df.shape
# Out:
# (4340, 8)

# %%
df.columns

# name: The name of the car, including the brand and model.
# year: The year in which the car was manufactured.
# selling_price: The price at which the car is being sold (presumably in Indian Rupees).
# km_driven: The total kilometers the car has been driven.
# fuel: The type of fuel used by the car (e.g., Petrol, Diesel, CNG).
# seller_type: The type of seller (e.g., Individual, Dealer, or Trustmark Dealer).
# transmission: The type of transmission system in the car (e.g., Manual or Automatic).
# owner: The ownership status of the car (e.g., First Owner, Second Owner, etc.).
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %%
df['year'].value_counts()
# Out:
# year
# 2017    466
# 2015    421
# 2012    415
# 2013    386
# 2014    367
# 2018    366
# 2016    357
# 2011    271
# 2010    234
# 2019    195
# 2009    193
# 2008    145
# 2007    134
# 2006    110
# 2005     85
# 2020     48
# 2004     42
# 2003     23
# 2002     21
# 2001     20
# 1998     12
# 2000     12
# 1999     10
# 1997      3
# 1996      2
# 1995      1
# 1992      1
# Name: count, dtype: int64

# %%
df['selling_price'].value_counts()
# Out:
# selling_price
# 300000    162
# 250000    125
# 350000    122
# 550000    107
# 600000    103
#          ...
# 749000      1
# 233000      1
# 614000      1
# 37500       1
# 865000      1
# Name: count, Length: 445, dtype: int64

# %%
df['km_driven'].value_counts()
# Out:
# km_driven
# 70000     236
# 80000     228
# 50000     222
# 120000    220
# 60000     215
#          ...
# 71500       1
# 12999       1
# 14700       1
# 92686       1
# 29976       1
# Name: count, Length: 770, dtype: int64

# %%
df['fuel'].value_counts()
# Out:
# fuel
# Diesel      2153
# Petrol      2123
# CNG           40
# LPG           23
# Electric       1
# Name: count, dtype: int64

# %%
df['transmission'].value_counts()
# Out:
# transmission
# Manual       3892
# Automatic     448
# Name: count, dtype: int64

# %%
df['owner'].value_counts()
# Out:
# owner
# First Owner             2832
# Second Owner            1106
# Third Owner              304
# Fourth & Above Owner      81
# Test Drive Car            17
# Name: count, dtype: int64

# %%
df['name'].value_counts()
# Out:
# name
# Maruti Swift Dzire VDI                            69
# Maruti Alto 800 LXI                               59
# Maruti Alto LXi                                   47
# Hyundai EON Era Plus                              35
# Maruti Alto LX                                    35
#                                                   ..
# Honda Brio 1.2 S Option MT                         1
# Mahindra Bolero Power Plus Plus Non AC BSIV PS     1
# Tata Indigo LS BSII                                1
# Force One EX                                       1
# Chevrolet Aveo 1.4 LT BSIV                         1
# Name: count, Length: 1491, dtype: int64

# %% [markdown]
# - create a new column car_age using year
# - this is used for find how car is old

# %%
df["car_age"] = 2025 - df["year"]

# %%
df['car_age']
# Out:
# 0       18
# 1       18
# 2       13
# 3        8
# 4       11
#         ..
# 4335    11
# 4336    11
# 4337    16
# 4338     9
# 4339     9
# Name: car_age, Length: 4340, dtype: int64

# %% [markdown]
# - change owner column categorical data to numeric form
# where first owner = 1 , second owner = 2, third owner = 3 , fourth and above owner = 4 and test drive car =0

# %%
map_with_owner = {
    "First Owner": 1,
    "Second Owner": 2,
    "Third Owner": 3,
    "Fourth & Above Owner": 4,
    "Test Drive Car": 0
}
df["owner"] = df["owner"].map(map_with_owner)

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission  owner  car_age
# 0  Individual       Manual      1       18
# 1  Individual       Manual      1       18
# 2  Individual       Manual      1       13
# 3  Individual       Manual      1        8
# 4  Individual       Manual      2       11

# %% [markdown]
# - change transmission categorical data to numeric from
# where manual = 1 and automatic = 0

# %%
t1={
    "Manual":1,
    "Automatic":0
}
df["transmission"] = df["transmission"].map(t1)

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type  transmission  owner  car_age
# 0  Individual             1      1       18
# 1  Individual             1      1       18
# 2  Individual             1      1       13
# 3  Individual             1      1        8
# 4  Individual             1      2       11

# %% [markdown]
# - rename owner column name

# %%
df.rename(columns={"owner":"1st to 4th = Owner and 0 = test drive car"},inplace=True)

# %% [markdown]
# - rename transmission column name

# %%
df.rename(columns={"transmission":"transmission(manual=1,aotumatic=0)"},inplace=True)

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type  transmission(manual=1,aotumatic=0)  \
# 0  Individual                                   1
# 1  Individual                                   1
# 2  Individual                                   1
# 3  Individual                                   1
# 4  Individual                                   1
#
#    1st to 4th = Owner and 0 = test drive car  car_age
# 0                                          1       18
# 1                                          1       18
# 2                                          1       13
# ...

# %% [markdown]
# - make a new column km_per_year based on km_driven and car age

# %%
df["km_per_year"] = (df["km_driven"] / df["car_age"].replace(0, 1)).astype(int)

# %% [markdown]
# - make a new column price_per_km based on selling_price and km_driven

# %%
df["price_per_km"] = (df["selling_price"] / df["km_driven"].replace(0, 1)).round(2)

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type  transmission(manual=1,aotumatic=0)  \
# 0  Individual                                   1
# 1  Individual                                   1
# 2  Individual                                   1
# 3  Individual                                   1
# 4  Individual                                   1
#
#    1st to 4th = Owner and 0 = test drive car  car_age  km_per_year  \
# 0                                          1       18         3888
# 1                                          1       18         2777
# ...

# %%
df['selling_price'].value_counts()
# Out:
# selling_price
# 300000    162
# 250000    125
# 350000    122
# 550000    107
# 600000    103
#          ...
# 749000      1
# 233000      1
# 614000      1
# 37500       1
# 865000      1
# Name: count, Length: 445, dtype: int64

# %%
df['name'].value_counts()
# Out:
# name
# Maruti Swift Dzire VDI                            69
# Maruti Alto 800 LXI                               59
# Maruti Alto LXi                                   47
# Hyundai EON Era Plus                              35
# Maruti Alto LX                                    35
#                                                   ..
# Honda Brio 1.2 S Option MT                         1
# Mahindra Bolero Power Plus Plus Non AC BSIV PS     1
# Tata Indigo LS BSII                                1
# Force One EX                                       1
# Chevrolet Aveo 1.4 LT BSIV                         1
# Name: count, Length: 1491, dtype: int64

# %%
df['name'].unique()
# Out:
# array(['Maruti 800 AC', 'Maruti Wagon R LXI Minor',
#        'Hyundai Verna 1.6 SX', ..., 'Mahindra Verito 1.5 D6 BSIII',
#        'Toyota Innova 2.5 VX (Diesel) 8 Seater BS IV',
#        'Hyundai i20 Magna 1.4 CRDi'], dtype=object)

# %% [markdown]
# - make a new column brand based on name column

# %%
df["brand"] = df["name"].str.split(" ").str[0]

# %%
df['brand'].value_counts()
# Out:
# brand
# Maruti           1280
# Hyundai           821
# Mahindra          365
# Tata              361
# Honda             252
# Ford              238
# Toyota            206
# Chevrolet         188
# Renault           146
# Volkswagen        107
# Skoda              68
# Nissan             64
# Audi               60
# BMW                39
# Fiat               37
# Datsun             37
# Mercedes-Benz      35
# Mitsubishi          6
# Jaguar              6
# Land                5
# Volvo               4
# Ambassador          4
# Jeep                3
# OpelCorsa           2
# MG                  2
# Force               1
# Daewoo              1
# Isuzu               1
# Kia                 1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df.groupby("brand")["selling_price"].mean().sort_values().plot(kind="bar", figsize=(10,5), color="skyblue")
plt.xlabel("Brand")
plt.ylabel("Avg Selling Price (INR)")
plt.xticks(rotation=90)
plt.show()

# %%
brand_counts = df["brand"].value_counts()
brand_counts.plot(kind="bar", figsize=(10, 5), color="purple")
plt.xlabel("Car Brand")
plt.ylabel("Number of Cars")
plt.title("Car Count by Brand")
plt.xticks(rotation=90)
plt.show()

# %%
luxury_brands = ["Audi", "BMW", "Mercedes-Benz", "Jaguar", "Volvo", "Land"]

df["car_type"] = df["brand"].apply(lambda x: 1 if x in luxury_brands else 0)

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type  transmission(manual=1,aotumatic=0)  \
# 0  Individual                                   1
# 1  Individual                                   1
# 2  Individual                                   1
# 3  Individual                                   1
# 4  Individual                                   1
#
#    1st to 4th = Owner and 0 = test drive car  car_age  km_per_year  \
# 0                                          1       18         3888
# 1                                          1       18         2777
# ...

# %%
brand_counts = df["car_type"].value_counts()
brand_counts.plot(kind="bar", figsize=(10, 5), color="green")
plt.xlabel("car type luxury=1 and non-luxury=0")
plt.ylabel("Number of Cars")
plt.title("Car Count by Brand")
plt.xticks(rotation=90)
plt.show()

# %%
df['car_type'].value_counts()
# Out:
# car_type
# 0    4191
# 1     149
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (4340, 13)

# %%
df.rename(columns={"car_type":"car : luxury=1 & non-luxury=0"}, inplace=True)

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type  transmission(manual=1,aotumatic=0)  \
# 0  Individual                                   1
# 1  Individual                                   1
# 2  Individual                                   1
# 3  Individual                                   1
# 4  Individual                                   1
#
#    1st to 4th = Owner and 0 = test drive car  car_age  km_per_year  \
# 0                                          1       18         3888
# 1                                          1       18         2777
# ...

# %%
plt.scatter(df["car : luxury=1 & non-luxury=0"], df["brand"], alpha=0.5, color="magenta")
plt.xlabel("Car Type (0 = Non-Luxury, 1 = Luxury)")
plt.ylabel("Selling Price (INR)")
plt.title("Car Type vs. Selling Price")
plt.show()

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type  transmission(manual=1,aotumatic=0)  \
# 0  Individual                                   1
# 1  Individual                                   1
# 2  Individual                                   1
# 3  Individual                                   1
# 4  Individual                                   1
#
#    1st to 4th = Owner and 0 = test drive car  car_age  km_per_year  \
# 0                                          1       18         3888
# 1                                          1       18         2777
# ...

# %%
df['seller_type'].value_counts()
# Out:
# seller_type
# Individual          3244
# Dealer               994
# Trustmark Dealer     102
# Name: count, dtype: int64

# %%
df['seller_type']
# Out:
# 0       Individual
# 1       Individual
# 2       Individual
# 3       Individual
# 4       Individual
#            ...
# 4335    Individual
# 4336    Individual
# 4337    Individual
# 4338    Individual
# 4339    Individual
# Name: seller_type, Length: 4340, dtype: object

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type  transmission(manual=1,aotumatic=0)  \
# 0  Individual                                   1
# 1  Individual                                   1
# 2  Individual                                   1
# 3  Individual                                   1
# 4  Individual                                   1
#
#    1st to 4th = Owner and 0 = test drive car  car_age  km_per_year  \
# 0                                          1       18         3888
# 1                                          1       18         2777
# ...

# %%
df.shape
# Out:
# (4340, 13)

# %%
df["eco_friendly=1 & non_eco_friendly=0"] = df["fuel"].apply(lambda x: 1 if x in ["CNG", "Electric", "LPG"] else 0)

# %%
df.head(25)
# Out:
#                                name  year  selling_price  km_driven    fuel  \
# 0                     Maruti 800 AC  2007          60000      70000  Petrol
# 1          Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2              Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3            Datsun RediGO T Option  2017         250000      46000  Petrol
# 4             Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
# 5              Maruti Alto LX BSIII  2007         140000     125000  Petrol
# 6         Hyundai Xcent 1.2 Kappa S  2016         550000      25000  Petrol
# 7          Tata Indigo Grand Petrol  2014         240000      60000  Petrol
# 8          Hyundai Creta 1.6 VTVT S  2015         850000      25000  Petrol
# 9          Maruti Celerio Green VXI  2017         365000      78000     CNG
# 10          Chevrolet Sail 1.2 Base  2015         260000      35000  Petrol
# ...

# %% [markdown]
# - use y= car : luxury=1 & non-luxury=0 and x= selling_price column for linear regression
# -> also found mse and r2

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score

# %%
x=df[['selling_price']] # Use double brackets to select a DataFrame instead of a Series
y=df['car : luxury=1 & non-luxury=0']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
mse = mean_squared_error(y_test, y_pred)

# %%
mse
# Out:
# 0.022247018291406517

# %%
r2 = r2_score(y_test, y_pred)

# %%
r2
# Out:
# 0.26183830936783115

# %%
plt.scatter(x_test, y_test, color="blue", label="Actual Data")
plt.plot(x_test, y_pred, color="red", linewidth=2, label="Regression Line")
plt.xlabel("Selling Price")
plt.ylabel("Car Type (Luxury=1, Non-Luxury=0)")
plt.show()

# %% [markdown]
# - outliers in each column

# %%
import seaborn as sns

# %%
column="selling_price"
plt.figure(figsize=(5, 4))
sns.boxplot(y=df[column])
plt.title(f"Outliers in {column}")
plt.ylabel(column)
plt.show()

# %%
column = "selling_price"
Q1 = df[column].quantile(0.25)
Q3 = df[column].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outlier_count = df[(df[column] < lower_bound) | (df[column] > upper_bound)].shape[0]

# %%
outlier_count
# Out:
# 271

# %%
df['selling_price'].value_counts()
# Out:
# selling_price
# 300000    162
# 250000    125
# 350000    122
# 550000    107
# 600000    103
#          ...
# 749000      1
# 233000      1
# 614000      1
# 37500       1
# 865000      1
# Name: count, Length: 445, dtype: int64

# %%
column="car_age"
plt.figure(figsize=(5, 4))
sns.boxplot(y=df[column])
plt.title(f"Outliers in {column}")
plt.ylabel(column)
plt.show()

# %%
column = "car_age"
Q1 = df[column].quantile(0.25)
Q3 = df[column].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outlier_count = df[(df[column] < lower_bound) | (df[column] > upper_bound)].shape[0]

# %%
outlier_count
# Out:
# 105

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x="seller_type", hue="fuel", data=df)

plt.xlabel("Seller Type")
plt.ylabel("Count")
plt.title("Seller Type vs Fuel Type")
plt.legend(title="Fuel Type")
plt.show()

# %%
plt.figure(figsize=(40, 10))
sns.countplot(x="brand", hue="transmission(manual=1,aotumatic=0)", data=df)

plt.xlabel("transmission automatic and manual")
plt.ylabel("brand")
plt.title("Seller Type vs Fuel Type")
plt.legend(title="Fuel Type")
plt.show()

# %%
column = "selling_price"
Q1 = df[column].quantile(0.25)
Q3 = df[column].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outlier_count = df[(df[column] < lower_bound) & (df[column] > upper_bound)].shape[0]

# %%
outlier_count
# Out:
# 0

# %%
df['selling_price'].isna().sum()
# Out:
# np.int64(0)
